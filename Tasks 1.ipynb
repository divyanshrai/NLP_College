# %%
import nltk
from nltk.corpus import stopwords 
from nltk.corpus import inaugural
from nltk.corpus import brown
from nltk.tokenize import TweetTokenizer
from nltk.tokenize import word_tokenize, sent_tokenize
#import matplotlib.pyplot as plt

# %%
1. Installing nltk
2. Downloading data/corpus
3. Inputing brown corpus
- Listing section headers
- loading data from one
4. Inputing inaugral
-sub ration headers
-loading data from headers
5. Listing any three lexicons #stopwords, names, unusual words
6. Using tweet tokenizer
7. Demonstration of basic pipeline - sentence segmentation, word segmentation, part of spech tagging
8. Demonstration of COCA

# %%
nltk.corpus.brown.fileids()
# Out:
# ['ca01',
#  'ca02',
#  'ca03',
#  'ca04',
#  'ca05',
#  'ca06',
#  'ca07',
#  'ca08',
#  'ca09',
#  'ca10',
#  'ca11',
#  'ca12',
#  'ca13',
#  'ca14',
#  'ca15',
#  'ca16',
#  'ca17',
#  'ca18',
#  'ca19',
#  'ca20',
#  'ca21',
#  'ca22',
#  'ca23',
#  'ca24',
#  'ca25',
#  'ca26',
#  'ca27',
#  'ca28',
#  'ca29',
#  'ca30',
#  'ca31',
#  'ca32',
#  'ca33',
#  'ca34',
#  'ca35',
#  'ca36',
#  'ca37',
#  'ca38',
#  'ca39',
#  'ca40',
#  'ca41',
#  'ca42',
#  'ca43',
#  'ca44',
#  'cb01',
#  'cb02',
#  'cb03',
#  'cb04',
#  'cb05',
#  'cb06',
#  'cb07',
#  'cb08',
#  'cb09',
#  'cb10',
#  'cb11',
#  'cb12',
#  'cb13',
#  'cb14',
#  'cb15',
#  'cb16',
#  'cb17',
#  'cb18',
#  'cb19',
#  'cb20',
#  'cb21',
#  'cb22',
#  'cb23',
#  'cb24',
#  'cb25',
#  'cb26',
#  'cb27',
#  'cc01',
#  'cc02',
#  'cc03',
#  'cc04',
#  'cc05',
#  'cc06',
#  'cc07',
#  'cc08',
#  'cc09',
#  'cc10',
#  'cc11',
#  'cc12',
#  'cc13',
#  'cc14',
#  'cc15',
#  'cc16',
#  'cc17',
#  'cd01',
#  'cd02',
# ...

# %%
words = nltk.corpus.brown.words('ca01')

# %%
words
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
stop_words = stopwords.words('english')
add_to_stop_words=[',','.','-',';',':']
stop_words.extend(add_to_stop_words)
stop_words=set(stop_words)

# %%
names=inaugural.fileids()
a=list(inaugural.words(fileids = names[0]))
for x in stop_words:
    while x in a: 
        a.remove(x)

# %%
nltk.FreqDist(a)
# Out:
# FreqDist({'I': 23, 'every': 8, 'public': 6, 'may': 6, 'government': 6, 'present': 5, 'one': 4, 'country': 4, 'citizens': 4, 'ought': 4, ...})

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
name = nltk.corpus.names
name.fileids()
male_names = name.words('male.txt')
female_names = name.words('female.txt')

# %%
male_names
# Out:
# ['Aamir',
#  'Aaron',
#  'Abbey',
#  'Abbie',
#  'Abbot',
#  'Abbott',
#  'Abby',
#  'Abdel',
#  'Abdul',
#  'Abdulkarim',
#  'Abdullah',
#  'Abe',
#  'Abel',
#  'Abelard',
#  'Abner',
#  'Abraham',
#  'Abram',
#  'Ace',
#  'Adair',
#  'Adam',
#  'Adams',
#  'Addie',
#  'Adger',
#  'Aditya',
#  'Adlai',
#  'Adnan',
#  'Adolf',
#  'Adolfo',
#  'Adolph',
#  'Adolphe',
#  'Adolpho',
#  'Adolphus',
#  'Adrian',
#  'Adrick',
#  'Adrien',
#  'Agamemnon',
#  'Aguinaldo',
#  'Aguste',
#  'Agustin',
#  'Aharon',
#  'Ahmad',
#  'Ahmed',
#  'Ahmet',
#  'Ajai',
#  'Ajay',
#  'Al',
#  'Alaa',
#  'Alain',
#  'Alan',
#  'Alasdair',
#  'Alastair',
#  'Albatros',
#  'Albert',
#  'Alberto',
#  'Albrecht',
#  'Alden',
#  'Aldis',
#  'Aldo',
#  'Aldric',
#  'Aldrich',
#  'Aldus',
#  'Aldwin',
#  'Alec',
#  'Aleck',
#  'Alejandro',
#  'Aleks',
#  'Aleksandrs',
#  'Alessandro',
#  'Alex',
#  'Alexander',
#  'Alexei',
#  'Alexis',
#  'Alf',
#  'Alfie',
#  'Alfonse',
#  'Alfonso',
#  'Alfonzo',
# ...

# %%
def unusual_words(text):
    text_vocab = set(w.lower() for w in text if w.isalpha())
    english_vocab = set(w.lower() for w in nltk.corpus.words.words())
    unusual = text_vocab - english_vocab
    return sorted(unusual)

# %%
unusual_words(a)
# Out:
# ['actuate',
#  'addressed',
#  'affairs',
#  'affections',
#  'aids',
#  'allotted',
#  'animosities',
#  'anxieties',
#  'arising',
#  'assembled',
#  'attachments',
#  'attributes',
#  'awakened',
#  'benefits',
#  'blessings',
#  'brings',
#  'called',
#  'cares',
#  'characters',
#  'circumstances',
#  'citizens',
#  'committed',
#  'communities',
#  'compared',
#  'concerns',
#  'conducts',
#  'consequences',
#  'consultations',
#  'consulted',
#  'contemplated',
#  'councils',
#  'deciding',
#  'declining',
#  'deficiencies',
#  'defining',
#  'delegated',
#  'deliberating',
#  'deliberations',
#  'designates',
#  'dispositions',
#  'disregards',
#  'duties',
#  'emoluments',
#  'emotions',
#  'endowments',
#  'entrusted',
#  'establishing',
#  'estimates',
#  'executing',
#  'exemplified',
#  'exists',
#  'expected',
#  'expenditures',
#  'expresses',
#  'feelings',
#  'fondest',
#  'fortified',
#  'freemen',
#  'functions',
#  'governments',
#  'guided',
#  'hands',
# ...

# %%
text="The part was soooo fun :D #superfun"
twtkn = TweetTokenizer()
twtkn.tokenize(text)
# Out:
# ['The', 'part', 'was', 'soooo', 'fun', ':D', '#superfun']

# %%
b=inaugural.words(fileids = names[0])

# %%
txt = "Sukanya, Rajib and Naba are my good friends. Sukanya is getting married next year. "
  
# sent_tokenize is one of instances of  
# PunktSentenceTokenizer from the nltk.tokenize.punkt module 
  
tokenized = sent_tokenize(txt) 
for i in tokenized: 
      
    # Word tokenizers is used to find the words  
    # and punctuation in a string 
    wordsList = nltk.word_tokenize(i) 
  
    # removing stop words from wordList 
    wordsList = [w for w in wordsList if not w in stop_words]  
  
    #  Using a Tagger. Which is part-of-speech  
    # tagger or POS-tagger.  
    tagged = nltk.pos_tag(wordsList)
    
    print(tagged)
# Out:
# [('Sukanya', 'NNP'), ('Rajib', 'NNP'), ('Naba', 'NNP'), ('good', 'JJ'), ('friends', 'NNS')]
# [('Sukanya', 'NNP'), ('getting', 'VBG'), ('married', 'VBN'), ('next', 'JJ'), ('year', 'NN')]

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True
